# %%
import numpy as np
import pandas as pd
import gym
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/crypto_data.csv')

# %%
df.head()
# Out:
#                   date     symbol    open    high     low   close  \
# 0  2020-12-25 05:00:00  1INCHUSDT  0.2000  3.0885  0.2000  2.5826
# 1  2020-12-25 06:00:00  1INCHUSDT  2.5824  2.6900  2.2249  2.5059
# 2  2020-12-25 07:00:00  1INCHUSDT  2.5152  2.8870  2.3609  2.6237
# 3  2020-12-25 08:00:00  1INCHUSDT  2.6318  2.8247  2.4650  2.6134
# 4  2020-12-25 09:00:00  1INCHUSDT  2.6104  2.7498  2.5629  2.6365
#
#    volume usdt  tradecount  token  hour     day
# 0     35530516       48768  1INCH     5  Friday
# 1     22440875       31099  1INCH     6  Friday
# 2     21300426       33001  1INCH     7  Friday
# 3     17491813       30459  1INCH     8  Friday
# 4      9919400       21023  1INCH     9  Friday

# %%
df.columns
# Out:
# Index(['date', 'symbol', 'open', 'high', 'low', 'close', 'volume usdt',
#        'tradecount', 'token', 'hour', 'day'],
#       dtype='object')

# %%
start_date = '2020-08-17 04:00:00'
end_date = '2023-10-19 23:00:00'

# %%
data_df = df.copy(deep = True)

# %%
data_df = data_df[(data_df['token'] == 'BTC') & (data_df['date'] >= start_date) & (data_df['date'] <= end_date)]

# %%
data_df.columns
# Out:
# Index(['date', 'symbol', 'open', 'high', 'low', 'close', 'volume usdt',
#        'tradecount', 'token', 'hour', 'day'],
#       dtype='object')

# %%
day_mapping = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
}

data_df['day'] = data_df['day'].apply(lambda x: day_mapping[x])

# %%
data_df['ema_13'] = data_df['close'].ewm(span=13).mean()
data_df['ema_25'] = data_df['close'].ewm(span=25).mean()
data_df['ema_32'] = data_df['close'].ewm(span=32).mean()
data_df['ema_100'] = data_df['close'].ewm(span=100).mean()
data_df['ema_200'] = data_df['close'].ewm(span=200).mean()

# %%
data_df['vol_close'] = (data_df['high'] - data_df['low']) / data_df['close']

# %%
# EMA for 2 hours (candles)
data_df['vol_close_ema_3'] = data_df['vol_close'].ewm(span=3, adjust=False).mean()

# EMA for 4 hours (candles)
data_df['vol_close_ema_6'] = data_df['vol_close'].ewm(span=6, adjust=False).mean()

# EMA for 8 hours ((candles)
data_df['vol_close_ema_12'] = data_df['vol_close'].ewm(span=12, adjust=False).mean()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27812 entries, 343607 to 371418
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27812 non-null  object
#  1   symbol            27812 non-null  object
#  2   open              27812 non-null  float64
#  3   high              27812 non-null  float64
#  4   low               27812 non-null  float64
#  5   close             27812 non-null  float64
#  6   volume usdt       27812 non-null  int64
#  7   tradecount        27812 non-null  int64
#  8   token             27812 non-null  object
#  9   hour              27812 non-null  int64
#  10  day               27812 non-null  int64
#  11  ema_13            27812 non-null  float64
#  12  ema_25            27812 non-null  float64
#  13  ema_32            27812 non-null  float64
#  14  ema_100           27812 non-null  float64
#  15  ema_200           27812 non-null  float64
#  16  vol_close         27812 non-null  float64
#  17  vol_close_ema_3   27812 non-null  float64
#  18  vol_close_ema_6   27812 non-null  float64
#  19  vol_close_ema_12  27812 non-null  float64
# dtypes: float64(13), int64(4), object(3)
# memory usage: 4.5+ MB

# %%
data_df['date'] = pd.to_datetime(data_df['date'])

# %%
columns_to_drop = ['symbol', 'token']
data_df = data_df.drop(columns=columns_to_drop)

# %%
data_df.to_csv('data_featured.csv', index=False)

# %%
train_df = data_df.copy(deep=True)
train_df.reset_index(drop=True, inplace=True)

# %%
train_df.head()
# Out:
#                  date      open      high       low     close  volume usdt  \
# 0 2020-08-17 04:00:00  11844.72  11858.91  11802.35  11809.38     17196539
# 1 2020-08-17 05:00:00  11809.39  11836.90  11790.00  11800.01     19958274
# 2 2020-08-17 06:00:00  11800.00  11846.74  11785.23  11806.37     19327915
# 3 2020-08-17 07:00:00  11806.37  11843.01  11792.32  11807.21     22698672
# 4 2020-08-17 08:00:00  11806.94  11885.00  11806.91  11868.77     28031116
#
#    tradecount  hour  day        ema_13        ema_25        ema_32  \
# 0       28800     4    1  11809.380000  11809.380000  11809.380000
# 1       28571     5    1  11804.334615  11804.507600  11804.548594
# 2       29762     6    1  11805.119921  11805.178699  11805.194058
# 3       33111     7    1  11805.768697  11805.749021  11805.746245
# 4       37458     8    1  11822.518351  11820.447106  11819.974205
#
#         ema_100       ema_200  vol_close  vol_close_ema_3  vol_close_ema_6  \
# 0  11809.380000  11809.380000   0.004789         0.004789         0.004789
# 1  11804.648150  11804.671575   0.003975         0.004382         0.004557
# 2  11805.233617  11805.243387   0.005210         0.004796         0.004743
# 3  11805.742633  11805.742440   0.004293         0.004545         0.004615
# 4  11818.857316  11818.601316   0.006579         0.005562         0.005176
#
#    vol_close_ema_12
# 0          0.004789
# 1          0.004664
# 2          0.004748
# 3          0.004678
# 4          0.004971

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import gym
from gym import spaces

# %%
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
            nn.Softmax(dim=-1)
        )
        self.critic = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self):
        raise NotImplementedError

    def act(self, state):
        action_probs = self.actor(state)
        dist = torch.distributions.Categorical(action_probs)
        action = dist.sample()
        return action.item(), dist.log_prob(action)

    def evaluate(self, state, action):
        action_probs = self.actor(state)
        dist = torch.distributions.Categorical(action_probs)
        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        state_value = self.critic(state)
        return action_logprobs, torch.squeeze(state_value), dist_entropy

# %%
class PPO:
    def __init__(self, state_dim, action_dim, lr, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs

        self.policy = ActorCritic(state_dim, action_dim)
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr=lr)

        self.policy_old = ActorCritic(state_dim, action_dim)
        self.policy_old.load_state_dict(self.policy.state_dict())

        self.MseLoss = nn.MSELoss()

    def update(self, memory):
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(memory.rewards), reversed(memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)

        rewards = torch.tensor(rewards, dtype=torch.float32)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)

        old_states = torch.squeeze(torch.stack(memory.states).detach()).float()
        old_actions = torch.squeeze(torch.stack(memory.actions).detach()).float()
        old_logprobs = torch.squeeze(torch.stack(memory.logprobs)).detach()

        for _ in range(self.K_epochs):
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)

            ratios = torch.exp(logprobs - old_logprobs.detach())

            advantages = rewards - state_values.detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy

            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()

        self.policy_old.load_state_dict(self.policy.state_dict())

# %%
# Memory
class Memory:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []

    def clear_memory(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]

# %%
# Crypto Trading Environment
class CryptoTradingEnv(gym.Env):
    def __init__(self, data, take_profit_position_range=(0.10, 0.80), stop_loss_position_range=(0.00, 0.15), max_stop_loss_position=0.30):
        super(CryptoTradingEnv, self).__init__()

        self.data = data
        self.n_steps = len(data)
        self.current_step = 0
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.position = 0
        self.position_open = 0
        self.num_trades = 0
        self.profit_loss = 0
        self.max_stop_loss_position = max_stop_loss_position

        self.take_profit_position_range = take_profit_position_range
        self.stop_loss_position_range = stop_loss_position_range

        self.action_space = spaces.Discrete(3)
        n_features = 15
        self.observation_space = spaces.Box(low=0, high=1, shape=(n_features,))

        self.episode_returns = []
        self.cumulative_returns = 0
        self.winning_trades = 0
        self.losing_trades = 0
        self.overall_rewards = 0

    def step(self, action):
        self.current_step += 1
        done = False

        reward = 0
        trade_outcome = 0

        if action == 1:  # Open Position
            if self.position == 0:
                position_size = 0.05 * self.balance
                self.position_open = self.data.loc[self.current_step, 'open']
                self.position = 1
                self.num_trades += 1
                print(f"Opened trade at step {self.current_step} with position size: {position_size:.2f}")
        elif action == 2:  # Close Position
            if self.position == 1:
                position_close = self.data.loc[self.current_step, 'open']
                trade_outcome = position_close - self.position_open
                self.profit_loss += trade_outcome
                self.position = 0
                self.position_open = 0
                print(f"Closed trade at step {self.current_step}")
                print(f"------------------------------> Trade outcome: {trade_outcome}")

                self.balance += trade_outcome

                if trade_outcome > 0:
                    if trade_outcome >= self.take_profit_position_range[0] * self.position:
                        reward = 1
                        self.winning_trades += 1
                        print("Trade reached take profit")
                elif trade_outcome < 0:
                    if abs(trade_outcome) >= self.max_stop_loss_position * self.position:
                        reward = -1.7
                        self.losing_trades += 1
                        print("Trade reached the maximum stop loss")
                    elif abs(trade_outcome) >= self.stop_loss_position_range[0] * self.position:
                        reward = -1
                        self.losing_trades += 1
                        print("Trade reached stop loss")
                    else:
                        reward = 0
                        print("Trade closed with no loss")

        if trade_outcome > 0:
            reward += 0.5
        print(f"Reward: {reward}")

        self.episode_returns.append(reward)
        self.cumulative_returns += reward
        self.overall_rewards += reward

        if self.current_step >= self.n_steps - 1:
            done = True

        next_state = self.get_observation()
        return next_state, reward, done, {}

    def reset(self):
        self.current_step = 0
        self.position = 0
        self.position_open = 0
        self.balance = self.initial_balance
        self.num_trades = 0
        self.profit_loss = 0
        self.episode_returns = []
        self.winning_trades = 0
        self.losing_trades = 0
        self.overall_rewards = 0
        return self.get_observation()

    def render(self, mode='human'):
        if mode == 'human':
            print(f"Step: {self.current_step}")
            print(f"Open Position: {self.position}")
            print(f"Trades: {self.num_trades} | Profit/Loss: {self.profit_loss:.2f}")
            print(f"Balance: {self.balance:.2f}")
            print(f"Winning Trades: {self.winning_trades} | Losing Trades: {self.losing_trades}")
            print(f"Overall Rewards: {self.overall_rewards:.2f}")
            print(self.data.loc[self.current_step])

    def get_observation(self):
        obs = self.data.loc[self.current_step, [
            'open', 'high', 'low', 'close', 'volume usdt', 'hour', 'day',
            'ema_13', 'ema_25', 'ema_32', 'ema_100', 'ema_200', 'vol_close_ema_3', 'vol_close_ema_6', 'vol_close_ema_12'
        ]].values.astype(np.float32)
        return obs / obs.max()

# %%
# Training loop
def train(env, agent, num_episodes, max_steps, print_interval):
    memory = Memory()

    for episode in range(num_episodes):
        state = env.reset()
        for t in range(max_steps):
            action, log_prob = agent.policy_old.act(torch.FloatTensor(state))
            next_state, reward, done, _ = env.step(action)

            memory.states.append(torch.FloatTensor(state))
            memory.actions.append(torch.tensor(action))
            memory.logprobs.append(log_prob)
            memory.rewards.append(reward)
            memory.is_terminals.append(done)

            state = next_state

            if done:
                break

        agent.update(memory)
        memory.clear_memory()

        if (episode + 1) % print_interval == 0:
            print(f"Episode {episode + 1}: Final Rewards: {env.cumulative_returns:.2f} | Total Trades: {env.num_trades}")

    return agent

# %%
data = train_df
data['date'] = pd.to_datetime(data['date'])

# %%
# Create environment and agent
env = CryptoTradingEnv(data)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

lr = 0.002
gamma = 0.99
K_epochs = 4
eps_clip = 0.2

agent = PPO(state_dim, action_dim, lr, gamma, K_epochs, eps_clip)

# %%
# Train the agent
num_episodes = 5
max_steps = 500
print_interval = 100

trained_agent = train(env, agent, num_episodes, max_steps, print_interval)

# Save the trained model
torch.save(trained_agent.policy.state_dict(), 'ppo_crypto_model.pth')

print("Training completed and model saved.")
# Out:
# Opened trade at step 1 with position size: 500.00
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 4
# ------------------------------> Trade outcome: -2.4499999999989086
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 5 with position size: 499.88
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 10
# ------------------------------> Trade outcome: 250.53000000000065
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 15 with position size: 512.40
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 18
# ------------------------------> Trade outcome: 8.909999999999854
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 22 with position size: 512.85
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 25
# ------------------------------> Trade outcome: -81.05999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 26 with position size: 508.80
# Reward: 0
# Closed trade at step 27
# ------------------------------> Trade outcome: 30.790000000000873
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 29 with position size: 510.34
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 39
# ------------------------------> Trade outcome: -270.0699999999997
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 40 with position size: 496.83
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 43
# ------------------------------> Trade outcome: 65.17000000000007
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 44 with position size: 500.09
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 53
# ------------------------------> Trade outcome: -156.76000000000022
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 58 with position size: 492.25
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 63
# ------------------------------> Trade outcome: -125.60999999999876
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 71 with position size: 485.97
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 74
# ------------------------------> Trade outcome: -43.3799999999992
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 78 with position size: 483.80
# Reward: 0
# Closed trade at step 79
# ------------------------------> Trade outcome: -2.7600000000002183
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 80 with position size: 483.67
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 84
# ------------------------------> Trade outcome: 37.20000000000073
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 85 with position size: 485.53
# Reward: 0
# Reward: 0
# Closed trade at step 87
# ------------------------------> Trade outcome: 18.700000000000728
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 96 with position size: 486.46
# Reward: 0
# Closed trade at step 97
# ------------------------------> Trade outcome: 3.4099999999998545
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 98 with position size: 486.63
# Reward: 0
# Closed trade at step 99
# ------------------------------> Trade outcome: -23.770000000000437
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 102 with position size: 485.44
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 111
# ------------------------------> Trade outcome: -105.27999999999884
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 119 with position size: 480.18
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 122
# ------------------------------> Trade outcome: 14.359999999998763
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 125 with position size: 480.90
# Reward: 0
# Closed trade at step 126
# ------------------------------> Trade outcome: 13.460000000000946
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 130 with position size: 481.57
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 138
# ------------------------------> Trade outcome: 71.25
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 143 with position size: 485.13
# Reward: 0
# Closed trade at step 144
# ------------------------------> Trade outcome: -9.3799999999992
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 147 with position size: 484.66
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 152
# ------------------------------> Trade outcome: -81.40999999999985
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 157 with position size: 480.59
# Reward: 0
# Closed trade at step 158
# ------------------------------> Trade outcome: -3.2399999999997817
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 163 with position size: 480.43
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 167
# ------------------------------> Trade outcome: 1.5100000000002183
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 168 with position size: 480.51
# Reward: 0
# Closed trade at step 169
# ------------------------------> Trade outcome: -5.6299999999992
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 171 with position size: 480.22
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 174
# ------------------------------> Trade outcome: 29.480000000001382
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 175 with position size: 481.70
# Reward: 0
# Reward: 0
# Closed trade at step 177
# ------------------------------> Trade outcome: 1.9700000000011642
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 186 with position size: 481.80
# Reward: 0
# Reward: 0
# Closed trade at step 188
# ------------------------------> Trade outcome: -6.920000000000073
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 192 with position size: 481.45
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 196
# ------------------------------> Trade outcome: -83.15999999999985
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 197 with position size: 477.29
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 202
# ------------------------------> Trade outcome: -134.46999999999935
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 204 with position size: 470.57
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 207
# ------------------------------> Trade outcome: -123.13999999999942
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 212 with position size: 464.41
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 220
# ------------------------------> Trade outcome: 29.6299999999992
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 224 with position size: 465.89
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 232
# ------------------------------> Trade outcome: 81.45000000000073
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 243 with position size: 469.97
# Reward: 0
# Reward: 0
# Closed trade at step 245
# ------------------------------> Trade outcome: -16.3799999999992
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 247 with position size: 469.15
# Reward: 0
# Closed trade at step 248
# ------------------------------> Trade outcome: -58.86999999999898
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 251 with position size: 466.20
# Reward: 0
# Closed trade at step 252
# ------------------------------> Trade outcome: 12.7599999999984
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 260 with position size: 466.84
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 263
# ------------------------------> Trade outcome: 43.32000000000153
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 267 with position size: 469.01
# Reward: 0
# Closed trade at step 268
# ------------------------------> Trade outcome: -53.3700000000008
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 269 with position size: 466.34
# Reward: 0
# Reward: 0
# Closed trade at step 271
# ------------------------------> Trade outcome: 42.31999999999971
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 273 with position size: 468.46
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 276
# ------------------------------> Trade outcome: 88.42000000000007
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 277 with position size: 472.88
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 281
# ------------------------------> Trade outcome: -15.049999999999272
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 282 with position size: 472.12
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 286
# ------------------------------> Trade outcome: -8.760000000000218
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 287 with position size: 471.69
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 292
# ------------------------------> Trade outcome: 85.39000000000124
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 293 with position size: 475.96
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 297
# ------------------------------> Trade outcome: -64.93000000000029
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 298 with position size: 472.71
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 301
# ------------------------------> Trade outcome: 71.82999999999993
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 303 with position size: 476.30
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 307
# ------------------------------> Trade outcome: -45.11999999999898
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 308 with position size: 474.04
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 316
# ------------------------------> Trade outcome: 127.05999999999949
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 317 with position size: 480.40
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 320
# ------------------------------> Trade outcome: 42.409999999999854
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 322 with position size: 482.52
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 325
# ------------------------------> Trade outcome: 38.06000000000131
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 335 with position size: 484.42
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 338
# ------------------------------> Trade outcome: -8.150000000001455
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 346 with position size: 484.01
# Reward: 0
# Closed trade at step 347
# ------------------------------> Trade outcome: 16.579999999999927
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 354 with position size: 484.84
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 358
# ------------------------------> Trade outcome: -3.5200000000004366
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 368 with position size: 484.67
# Reward: 0
# Closed trade at step 369
# ------------------------------> Trade outcome: 30.960000000000946
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 372 with position size: 486.21
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 376
# ------------------------------> Trade outcome: -81.92000000000007
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 378 with position size: 482.12
# Reward: 0
# Closed trade at step 379
# ------------------------------> Trade outcome: -43.099999999998545
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 381 with position size: 479.96
# Reward: 0
# Closed trade at step 382
# ------------------------------> Trade outcome: -11.290000000000873
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 383 with position size: 479.40
# Reward: 0
# Closed trade at step 384
# ------------------------------> Trade outcome: -22.979999999999563
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 386 with position size: 478.25
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 389
# ------------------------------> Trade outcome: -157.02999999999884
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 391 with position size: 470.40
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 403
# ------------------------------> Trade outcome: -148.9400000000005
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 404 with position size: 462.95
# Reward: 0
# Reward: 0
# Closed trade at step 406
# ------------------------------> Trade outcome: 34.399999999999636
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 407 with position size: 464.67
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 414
# ------------------------------> Trade outcome: -82.39999999999964
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 423 with position size: 460.55
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 427
# ------------------------------> Trade outcome: 11.209999999999127
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 428 with position size: 461.11
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 431
# ------------------------------> Trade outcome: 123.03999999999905
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 434 with position size: 467.26
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 445
# ------------------------------> Trade outcome: 151.09000000000015
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 450 with position size: 474.82
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 453
# ------------------------------> Trade outcome: -64.70999999999913
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 458 with position size: 471.58
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 461
# ------------------------------> Trade outcome: -81.02000000000044
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 469 with position size: 467.53
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 473
# ------------------------------> Trade outcome: -159.70999999999913
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 475 with position size: 459.55
# Reward: 0
# Closed trade at step 476
# ------------------------------> Trade outcome: 185.51000000000022
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 477 with position size: 468.82
# Reward: 0
# Closed trade at step 478
# ------------------------------> Trade outcome: -90.34000000000015
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 479 with position size: 464.31
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 486
# ------------------------------> Trade outcome: 65.45999999999913
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 488 with position size: 467.58
# Reward: 0
# Closed trade at step 489
# ------------------------------> Trade outcome: -20.590000000000146
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 493 with position size: 466.55
# Reward: 0
# Reward: 0
# Closed trade at step 495
# ------------------------------> Trade outcome: -4.940000000000509
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 498 with position size: 466.30
# Reward: 0
# Reward: 0
# Closed trade at step 500
# ------------------------------> Trade outcome: -62.48999999999978
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 1 with position size: 500.00
# Reward: 0
# Reward: 0
# Closed trade at step 3
# ------------------------------> Trade outcome: -3.0199999999986176
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 7 with position size: 499.85
# Reward: 0
# Reward: 0
# Closed trade at step 9
# ------------------------------> Trade outcome: 20.06999999999971
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 15 with position size: 500.85
# Reward: 0
# Closed trade at step 16
# ------------------------------> Trade outcome: 21.890000000001237
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 19 with position size: 501.95
# Reward: 0
# Closed trade at step 20
# ------------------------------> Trade outcome: -90.38000000000102
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 22 with position size: 497.43
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 30
# ------------------------------> Trade outcome: -109.35000000000036
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 33 with position size: 491.96
# Reward: 0
# Closed trade at step 34
# ------------------------------> Trade outcome: -92.91000000000167
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 42 with position size: 487.31
# Reward: 0
# Closed trade at step 43
# ------------------------------> Trade outcome: -13.649999999999636
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 47 with position size: 486.63
# Reward: 0
# Reward: 0
# Closed trade at step 49
# ------------------------------> Trade outcome: -157.90999999999985
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 51 with position size: 478.74
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 62
# ------------------------------> Trade outcome: 46.98999999999978
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 67 with position size: 481.09
# Reward: 0
# Reward: 0
# Closed trade at step 69
# ------------------------------> Trade outcome: 48.43999999999869
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 70 with position size: 483.51
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 73
# ------------------------------> Trade outcome: -41.1299999999992
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 74 with position size: 481.45
# Reward: 0
# Closed trade at step 75
# ------------------------------> Trade outcome: 66.97999999999956
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 77 with position size: 484.80
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 80
# ------------------------------> Trade outcome: 57.1299999999992
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 81 with position size: 487.66
# Reward: 0
# Reward: 0
# Closed trade at step 83
# ------------------------------> Trade outcome: 58.77000000000044
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 92 with position size: 490.60
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 96
# ------------------------------> Trade outcome: 13.039999999999054
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 100 with position size: 491.25
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 103
# ------------------------------> Trade outcome: -71.79999999999927
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 108 with position size: 487.66
# Reward: 0
# Closed trade at step 109
# ------------------------------> Trade outcome: -59.63999999999942
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 112 with position size: 484.68
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 123
# ------------------------------> Trade outcome: -106.86999999999898
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 125 with position size: 479.33
# Reward: 0
# Closed trade at step 126
# ------------------------------> Trade outcome: 13.460000000000946
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 127 with position size: 480.01
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 131
# ------------------------------> Trade outcome: 49.36000000000058
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 135 with position size: 482.47
# Reward: 0
# Reward: 0
# Closed trade at step 137
# ------------------------------> Trade outcome: 6.779999999998836
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 142 with position size: 482.81
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 146
# ------------------------------> Trade outcome: -66.73999999999978
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 147 with position size: 479.48
# Reward: 0
# Reward: 0
# Closed trade at step 149
# ------------------------------> Trade outcome: -37.95000000000073
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 151 with position size: 477.58
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 156
# ------------------------------> Trade outcome: 124.55000000000109
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 158 with position size: 483.81
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 161
# ------------------------------> Trade outcome: 33.25
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 163 with position size: 485.47
# Reward: 0
# Closed trade at step 164
# ------------------------------> Trade outcome: -0.5999999999985448
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 167 with position size: 485.44
# Reward: 0
# Reward: 0
# Closed trade at step 169
# ------------------------------> Trade outcome: 28.540000000000873
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 170 with position size: 486.87
# Reward: 0
# Closed trade at step 171
# ------------------------------> Trade outcome: 97.42000000000007
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 174 with position size: 491.74
# Reward: 0
# Reward: 0
# Closed trade at step 176
# ------------------------------> Trade outcome: 10.840000000000146
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 179 with position size: 492.28
# Reward: 0
# Reward: 0
# Closed trade at step 181
# ------------------------------> Trade outcome: 28.459999999999127
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 186 with position size: 493.70
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 189
# ------------------------------> Trade outcome: -15.44000000000051
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 191 with position size: 492.93
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 195
# ------------------------------> Trade outcome: -67.52000000000044
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 197 with position size: 489.55
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 202
# ------------------------------> Trade outcome: -134.46999999999935
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 203 with position size: 482.83
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 206
# ------------------------------> Trade outcome: -161.59000000000015
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 207 with position size: 474.75
# Reward: 0
# Reward: 0
# Closed trade at step 209
# ------------------------------> Trade outcome: -38.06000000000131
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 213 with position size: 472.85
# Reward: 0
# Closed trade at step 214
# ------------------------------> Trade outcome: 52.67000000000007
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 215 with position size: 475.48
# Reward: 0
# Reward: 0
# Closed trade at step 217
# ------------------------------> Trade outcome: -40.73999999999978
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 218 with position size: 473.44
# Reward: 0
# Closed trade at step 219
# ------------------------------> Trade outcome: -38.100000000000364
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 223 with position size: 471.54
# Reward: 0
# Reward: 0
# Closed trade at step 225
# ------------------------------> Trade outcome: -81.1299999999992
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 226 with position size: 467.48
# Reward: 0
# Reward: 0
# Closed trade at step 228
# ------------------------------> Trade outcome: 77.54000000000087
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 234 with position size: 471.36
# Reward: 0
# Closed trade at step 235
# ------------------------------> Trade outcome: -18.399999999999636
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 240 with position size: 470.44
# Reward: 0
# Closed trade at step 241
# ------------------------------> Trade outcome: -18.1200000000008
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 242 with position size: 469.53
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 248
# ------------------------------> Trade outcome: -40.43000000000029
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 249 with position size: 467.51
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 258
# ------------------------------> Trade outcome: -64.07000000000153
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 260 with position size: 464.31
# Reward: 0
# Reward: 0
# Closed trade at step 262
# ------------------------------> Trade outcome: 47.36000000000058
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 263 with position size: 466.68
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 268
# ------------------------------> Trade outcome: 5.929999999998472
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 269 with position size: 466.97
# Reward: 0
# Reward: 0
# Closed trade at step 271
# ------------------------------> Trade outcome: 42.31999999999971
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 275 with position size: 469.09
# Reward: 0
# Closed trade at step 276
# ------------------------------> Trade outcome: 92.6299999999992
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 277 with position size: 473.72
# Reward: 0
# Closed trade at step 278
# ------------------------------> Trade outcome: -35.51000000000022
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 279 with position size: 471.94
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 283
# ------------------------------> Trade outcome: -8.69000000000051
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 285 with position size: 471.51
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 288
# ------------------------------> Trade outcome: 11.81000000000131
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 290 with position size: 472.10
# Reward: 0
# Reward: 0
# Closed trade at step 292
# ------------------------------> Trade outcome: 51.48000000000138
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 294 with position size: 474.67
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 299
# ------------------------------> Trade outcome: -50.55999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 307 with position size: 472.15
# Reward: 0
# Closed trade at step 308
# ------------------------------> Trade outcome: -15.700000000000728
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 310 with position size: 471.36
# Reward: 0
# Closed trade at step 311
# ------------------------------> Trade outcome: 4.149999999999636
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 312 with position size: 471.57
# Reward: 0
# Reward: 0
# Closed trade at step 314
# ------------------------------> Trade outcome: -22.329999999999927
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 315 with position size: 470.45
# Reward: 0
# Closed trade at step 316
# ------------------------------> Trade outcome: 8.569999999999709
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 318 with position size: 470.88
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 324
# ------------------------------> Trade outcome: 33.19999999999891
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 325 with position size: 472.54
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 329
# ------------------------------> Trade outcome: -27.210000000000946
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 330 with position size: 471.18
# Reward: 0
# Closed trade at step 331
# ------------------------------> Trade outcome: 54.719999999999345
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 333 with position size: 473.92
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 336
# ------------------------------> Trade outcome: -17.110000000000582
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 338 with position size: 473.06
# Reward: 0
# Reward: 0
# Closed trade at step 340
# ------------------------------> Trade outcome: -49.409999999999854
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 341 with position size: 470.59
# Reward: 0
# Reward: 0
# Closed trade at step 343
# ------------------------------> Trade outcome: 28.76000000000022
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 344 with position size: 472.03
# Reward: 0
# Closed trade at step 345
# ------------------------------> Trade outcome: 38.850000000000364
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 346 with position size: 473.97
# Reward: 0
# Closed trade at step 347
# ------------------------------> Trade outcome: 16.579999999999927
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 349 with position size: 474.80
# Reward: 0
# Closed trade at step 350
# ------------------------------> Trade outcome: -2.1299999999991996
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 364 with position size: 474.69
# Reward: 0
# Closed trade at step 365
# ------------------------------> Trade outcome: -10.889999999999418
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 366 with position size: 474.15
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 371
# ------------------------------> Trade outcome: -45.029999999998836
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 372 with position size: 471.90
# Reward: 0
# Closed trade at step 373
# ------------------------------> Trade outcome: -43.11000000000058
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 374 with position size: 469.74
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 377
# ------------------------------> Trade outcome: 46.56000000000131
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 378 with position size: 472.07
# Reward: 0
# Closed trade at step 379
# ------------------------------> Trade outcome: -43.099999999998545
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 381 with position size: 469.92
# Reward: 0
# Reward: 0
# Closed trade at step 383
# ------------------------------> Trade outcome: -41.11000000000058
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 385 with position size: 467.86
# Reward: 0
# Reward: 0
# Closed trade at step 387
# ------------------------------> Trade outcome: -82.84999999999854
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 393 with position size: 463.72
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 397
# ------------------------------> Trade outcome: -127.53999999999905
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 398 with position size: 457.34
# Reward: 0
# Reward: 0
# Closed trade at step 400
# ------------------------------> Trade outcome: 35.79999999999927
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 402 with position size: 459.13
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 410
# ------------------------------> Trade outcome: -93.78000000000065
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 411 with position size: 454.44
# Reward: 0
# Reward: 0
# Closed trade at step 413
# ------------------------------> Trade outcome: 107.71999999999935
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 417 with position size: 459.83
# Reward: 0
# Closed trade at step 418
# ------------------------------> Trade outcome: 98.11000000000058
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 420 with position size: 464.73
# Reward: 0
# Closed trade at step 421
# ------------------------------> Trade outcome: -108.73000000000138
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 423 with position size: 459.30
# Reward: 0
# Reward: 0
# Closed trade at step 425
# ------------------------------> Trade outcome: 124.02000000000044
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 427 with position size: 465.50
# Reward: 0
# Reward: 0
# Closed trade at step 429
# ------------------------------> Trade outcome: -361.9300000000003
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 430 with position size: 447.40
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 435
# ------------------------------> Trade outcome: -34.81999999999971
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 436 with position size: 445.66
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 439
# ------------------------------> Trade outcome: 166.67000000000007
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 441 with position size: 453.99
# Reward: 0
# Closed trade at step 442
# ------------------------------> Trade outcome: -91.61999999999898
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 443 with position size: 449.41
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 448
# ------------------------------> Trade outcome: 191.83999999999833
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 451 with position size: 459.00
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 454
# ------------------------------> Trade outcome: 21.779999999998836
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 455 with position size: 460.09
# Reward: 0
# Reward: 0
# Closed trade at step 457
# ------------------------------> Trade outcome: -18.980000000001382
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 461 with position size: 459.14
# Reward: 0
# Reward: 0
# Closed trade at step 463
# ------------------------------> Trade outcome: -37.52000000000044
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 468 with position size: 457.27
# Reward: 0
# Closed trade at step 469
# ------------------------------> Trade outcome: -33.969999999999345
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 475 with position size: 455.57
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 479
# ------------------------------> Trade outcome: 170.6800000000003
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 480 with position size: 464.10
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 483
# ------------------------------> Trade outcome: -10.5099999999984
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 486 with position size: 463.58
# Reward: 0
# Closed trade at step 487
# ------------------------------> Trade outcome: 14.19000000000051
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 491 with position size: 464.29
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 497
# ------------------------------> Trade outcome: -5.850000000000364
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 498 with position size: 464.00
# Reward: 0
# Closed trade at step 499
# ------------------------------> Trade outcome: -107.30999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 2 with position size: 500.00
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 8
# ------------------------------> Trade outcome: 108.67000000000007
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 9 with position size: 505.43
# Reward: 0
# Closed trade at step 10
# ------------------------------> Trade outcome: 238.60000000000036
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 12 with position size: 517.36
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 17
# ------------------------------> Trade outcome: -107.80999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 19 with position size: 511.97
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 22
# ------------------------------> Trade outcome: -44.20000000000073
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 28 with position size: 509.76
# Reward: 0
# Reward: 0
# Closed trade at step 30
# ------------------------------> Trade outcome: -42.93000000000029
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 31 with position size: 507.62
# Reward: 0
# Reward: 0
# Closed trade at step 33
# ------------------------------> Trade outcome: -28.039999999999054
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 36 with position size: 506.21
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 44
# ------------------------------> Trade outcome: 10.69000000000051
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 46 with position size: 506.75
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 53
# ------------------------------> Trade outcome: -180.04999999999927
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 57 with position size: 497.75
# Reward: 0
# Closed trade at step 58
# ------------------------------> Trade outcome: 8.159999999999854
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 59 with position size: 498.15
# Reward: 0
# Reward: 0
# Closed trade at step 61
# ------------------------------> Trade outcome: 3.5799999999999272
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 63 with position size: 498.33
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 68
# ------------------------------> Trade outcome: 16.2599999999984
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 74 with position size: 499.15
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 77
# ------------------------------> Trade outcome: 64.05999999999949
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 80 with position size: 502.35
# Reward: 0
# Reward: 0
# Closed trade at step 82
# ------------------------------> Trade outcome: -0.7600000000002183
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 83 with position size: 502.31
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 87
# ------------------------------> Trade outcome: 17.649999999999636
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 91 with position size: 503.19
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 100
# ------------------------------> Trade outcome: 15.719999999999345
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 105 with position size: 503.98
# Reward: 0
# Closed trade at step 106
# ------------------------------> Trade outcome: -62.94999999999891
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 107 with position size: 500.83
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 116
# ------------------------------> Trade outcome: -204.52000000000044
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 120 with position size: 490.61
# Reward: 0
# Reward: 0
# Closed trade at step 122
# ------------------------------> Trade outcome: -2.710000000000946
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 123 with position size: 490.47
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 127
# ------------------------------> Trade outcome: 5.979999999999563
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 128 with position size: 490.77
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 131
# ------------------------------> Trade outcome: 58.36000000000058
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 132 with position size: 493.69
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 137
# ------------------------------> Trade outcome: 26.209999999999127
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 138 with position size: 495.00
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 141
# ------------------------------> Trade outcome: -21.80000000000109
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 146 with position size: 493.91
# Reward: 0
# Closed trade at step 147
# ------------------------------> Trade outcome: 30.100000000000364
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 150 with position size: 495.41
# Reward: 0
# Reward: 0
# Closed trade at step 152
# ------------------------------> Trade outcome: -61.67999999999847
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 153 with position size: 492.33
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 157
# ------------------------------> Trade outcome: 74.98999999999978
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 161 with position size: 496.08
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 173
# ------------------------------> Trade outcome: 114.96999999999935
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 174 with position size: 501.83
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 178
# ------------------------------> Trade outcome: -20.200000000000728
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 179 with position size: 500.82
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 183
# ------------------------------> Trade outcome: 4.4099999999998545
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 184 with position size: 501.04
# Reward: 0
# Reward: 0
# Closed trade at step 186
# ------------------------------> Trade outcome: 6.730000000001382
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 189 with position size: 501.37
# Reward: 0
# Closed trade at step 190
# ------------------------------> Trade outcome: 20.75
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 193 with position size: 502.41
# Reward: 0
# Closed trade at step 194
# ------------------------------> Trade outcome: -13.030000000000655
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 195 with position size: 501.76
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 204
# ------------------------------> Trade outcome: -193.15999999999985
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 206 with position size: 492.10
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 217
# ------------------------------> Trade outcome: 121.51000000000022
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 220 with position size: 498.18
# Reward: 0
# Reward: 0
# Closed trade at step 222
# ------------------------------> Trade outcome: 18.360000000000582
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 223 with position size: 499.10
# Reward: 0
# Closed trade at step 224
# ------------------------------> Trade outcome: -13.05999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 227 with position size: 498.44
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 230
# ------------------------------> Trade outcome: 9.979999999999563
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 232 with position size: 498.94
# Reward: 0
# Reward: 0
# Closed trade at step 234
# ...
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 110
# ------------------------------> Trade outcome: -113.97999999999956
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 113 with position size: 522.30
# Reward: 0
# Closed trade at step 114
# ------------------------------> Trade outcome: -80.44000000000051
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 115 with position size: 518.27
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 119
# ------------------------------> Trade outcome: -95.92000000000007
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 121 with position size: 513.48
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 124
# ------------------------------> Trade outcome: 156.77000000000044
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 125 with position size: 521.32
# Reward: 0
# Closed trade at step 126
# ------------------------------> Trade outcome: 13.460000000000946
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 128 with position size: 521.99
# Reward: 0
# Closed trade at step 129
# ------------------------------> Trade outcome: 27.93000000000029
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 130 with position size: 523.39
# Reward: 0
# Closed trade at step 131
# ------------------------------> Trade outcome: 23.600000000000364
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 135 with position size: 524.57
# Reward: 0
# Closed trade at step 136
# ------------------------------> Trade outcome: -12.270000000000437
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 137 with position size: 523.95
# Reward: 0
# Closed trade at step 138
# ------------------------------> Trade outcome: 57.70000000000073
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 142 with position size: 526.84
# Reward: 0
# Reward: 0
# Closed trade at step 144
# ------------------------------> Trade outcome: -45.409999999999854
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 147 with position size: 524.57
# Reward: 0
# Closed trade at step 148
# ------------------------------> Trade outcome: 8.5099999999984
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 150 with position size: 524.99
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 160
# ------------------------------> Trade outcome: 96.76000000000022
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 162 with position size: 529.83
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 165
# ------------------------------> Trade outcome: -40.18000000000029
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 166 with position size: 527.82
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 174
# ------------------------------> Trade outcome: 146.38000000000102
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 177 with position size: 535.14
# Reward: 0
# Closed trade at step 178
# ------------------------------> Trade outcome: -13.3700000000008
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 179 with position size: 534.47
# Reward: 0
# Reward: 0
# Closed trade at step 181
# ------------------------------> Trade outcome: 28.459999999999127
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 182 with position size: 535.89
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 191
# ------------------------------> Trade outcome: -67.17000000000007
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 193 with position size: 532.54
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 199
# ------------------------------> Trade outcome: -40.77000000000044
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 203 with position size: 530.50
# Reward: 0
# Closed trade at step 204
# ------------------------------> Trade outcome: 26.969999999999345
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 206 with position size: 531.85
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 212
# ------------------------------> Trade outcome: 87.55999999999949
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 213 with position size: 536.22
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 222
# ------------------------------> Trade outcome: 84.95000000000073
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 225 with position size: 540.47
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 230
# ------------------------------> Trade outcome: 139.70999999999913
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 233 with position size: 547.46
# Reward: 0
# Reward: 0
# Closed trade at step 235
# ------------------------------> Trade outcome: -55.710000000000946
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 237 with position size: 544.67
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 243
# ------------------------------> Trade outcome: -68.80000000000109
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 246 with position size: 541.23
# Reward: 0
# Closed trade at step 247
# ------------------------------> Trade outcome: -48.11000000000058
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 249 with position size: 538.83
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 253
# ------------------------------> Trade outcome: -79.27000000000044
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 255 with position size: 534.86
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 263
# ------------------------------> Trade outcome: 116.79000000000087
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 264 with position size: 540.70
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 267
# ------------------------------> Trade outcome: 52.909999999999854
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 268 with position size: 543.35
# Reward: 0
# Reward: 0
# Closed trade at step 270
# ------------------------------> Trade outcome: 60.61000000000058
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 271 with position size: 546.38
# Reward: 0
# Closed trade at step 272
# ------------------------------> Trade outcome: 34.26000000000022
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 274 with position size: 548.09
# Reward: 0
# Reward: 0
# Closed trade at step 276
# ------------------------------> Trade outcome: 68.65999999999985
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 277 with position size: 551.52
# Reward: 0
# Reward: 0
# Closed trade at step 279
# ------------------------------> Trade outcome: -28.23999999999978
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 281 with position size: 550.11
# Reward: 0
# Closed trade at step 282
# ------------------------------> Trade outcome: -6.030000000000655
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 284 with position size: 549.81
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 287
# ------------------------------> Trade outcome: -54.01000000000022
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 288 with position size: 547.11
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 291
# ------------------------------> Trade outcome: 22.30999999999949
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 299 with position size: 548.23
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 307
# ------------------------------> Trade outcome: -11.05999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 311 with position size: 547.67
# Reward: 0
# Closed trade at step 312
# ------------------------------> Trade outcome: -13.049999999999272
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 315 with position size: 547.02
# Reward: 0
# Closed trade at step 316
# ------------------------------> Trade outcome: 8.569999999999709
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 318 with position size: 547.45
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 326
# ------------------------------> Trade outcome: 58.55999999999949
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 329 with position size: 550.38
# Reward: 0
# Closed trade at step 330
# ------------------------------> Trade outcome: -36.75
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 331 with position size: 548.54
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 339
# ------------------------------> Trade outcome: 18.890000000001237
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 341 with position size: 549.48
# Reward: 0
# Closed trade at step 342
# ------------------------------> Trade outcome: 16.409999999999854
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 343 with position size: 550.30
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 347
# ------------------------------> Trade outcome: 121.53000000000065
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 352 with position size: 556.38
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 357
# ------------------------------> Trade outcome: -112.78000000000065
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 359 with position size: 550.74
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 363
# ------------------------------> Trade outcome: 231.63999999999942
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 364 with position size: 562.32
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 376
# ------------------------------> Trade outcome: 33.67000000000007
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 379 with position size: 564.01
# Reward: 0
# Reward: 0
# Closed trade at step 381
# ------------------------------> Trade outcome: -73.93000000000029
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 382 with position size: 560.31
# Reward: 0
# Reward: 0
# Closed trade at step 384
# ------------------------------> Trade outcome: -52.79999999999927
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 387 with position size: 557.67
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 390
# ------------------------------> Trade outcome: -52.530000000000655
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 396 with position size: 555.04
# Reward: 0
# Closed trade at step 397
# ------------------------------> Trade outcome: -28.55999999999949
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 401 with position size: 553.62
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 404
# ------------------------------> Trade outcome: 33.9900000000016
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 405 with position size: 555.32
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 408
# ------------------------------> Trade outcome: -59.780000000000655
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 409 with position size: 552.33
# Reward: 0
# Reward: 0
# Closed trade at step 411
# ------------------------------> Trade outcome: 1.8700000000008004
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Reward: 0
# Opened trade at step 414 with position size: 552.42
# Reward: 0
# Reward: 0
# Closed trade at step 416
# ------------------------------> Trade outcome: -134.29999999999927
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 421 with position size: 545.70
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 428
# ------------------------------> Trade outcome: -423.2599999999984
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 431 with position size: 524.54
# Reward: 0
# Closed trade at step 432
# ------------------------------> Trade outcome: 4.079999999999927
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 433 with position size: 524.75
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 438
# ------------------------------> Trade outcome: 231.16000000000167
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 440 with position size: 536.30
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 448
# ------------------------------> Trade outcome: 147.60999999999876
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 449 with position size: 543.68
# Reward: 0
# Closed trade at step 450
# ------------------------------> Trade outcome: -40.25
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 451 with position size: 541.67
# Reward: 0
# Closed trade at step 452
# ------------------------------> Trade outcome: -15.700000000000728
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 453 with position size: 540.89
# Reward: 0
# Reward: 0
# Closed trade at step 455
# ------------------------------> Trade outcome: -48.88999999999942
# Trade reached the maximum stop loss
# Reward: -1.7
# Opened trade at step 456 with position size: 538.44
# Reward: 0
# Closed trade at step 457
# ------------------------------> Trade outcome: 5.0900000000001455
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 458 with position size: 538.70
# Reward: 0
# Reward: 0
# Closed trade at step 460
# ------------------------------> Trade outcome: 3.7700000000004366
# Trade reached take profit
# Reward: 1.5
# Reward: 0
# Opened trade at step 462 with position size: 538.89
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 465
# ------------------------------> Trade outcome: -285.0799999999999
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Opened trade at step 468 with position size: 524.63
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 478
# ------------------------------> Trade outcome: -154.78999999999905
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Opened trade at step 480 with position size: 516.89
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 485
# ------------------------------> Trade outcome: 74.45000000000073
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 486 with position size: 520.61
# Reward: 0
# Reward: 0
# Reward: 0
# Closed trade at step 489
# ------------------------------> Trade outcome: 28.409999999999854
# Trade reached take profit
# Reward: 1.5
# Opened trade at step 490 with position size: 522.04
# Reward: 0
# Reward: 0
# Closed trade at step 492
# ------------------------------> Trade outcome: -50.539999999999054
# Trade reached the maximum stop loss
# Reward: -1.7
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Opened trade at step 497 with position size: 519.51
# Reward: 0
# Reward: 0
# Reward: 0
# Reward: 0
# Training completed and model saved.

# %%
# Validation phase
val_data = data.copy()  # You might want to use a separate validation dataset
val_env = CryptoTradingEnv(val_data)

state = val_env.reset()
done = False
total_reward = 0

while not done:
    action, _ = trained_agent.policy_old.act(torch.FloatTensor(state))
    state, reward, done, _ = val_env.step(action)
    total_reward += reward
    val_env.render()
print(f"Validation Phase - Total Reward: {total_reward:.2f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Step: 27624
# Open Position: 1
# Trades: 4334 | Profit/Loss: 19941.92
# Balance: 29941.92
# Winning Trades: 2246 | Losing Trades: 2087
# Overall Rewards: -178.90
# date                2023-10-12 04:00:00
# open                           26847.07
# high                           26849.99
# low                            26815.01
# close                           26821.1
# volume usdt                    12777077
# tradecount                        22648
# hour                                  4
# day                                   4
# ema_13                     26848.068878
# ema_25                     26944.249886
# ema_32                      27002.45525
# ema_100                    27341.514681
# ema_200                     27430.49581
# vol_close                      0.001304
# vol_close_ema_3                0.002751
# vol_close_ema_6                0.003404
# vol_close_ema_12               0.004006
# Name: 27624, dtype: object
# Reward: 0
# Step: 27625
# Open Position: 1
# Trades: 4334 | Profit/Loss: 19941.92
# Balance: 29941.92
# Winning Trades: 2246 | Losing Trades: 2087
# Overall Rewards: -178.90
# date                2023-10-12 05:00:00
# open                           26821.11
# high                           26876.86
# low                            26783.14
# close                          26876.85
# volume usdt                    15195565
# tradecount                        26459
# hour                                  5
# day                                   4
# ema_13                     26852.180467
# ema_25                     26939.065279
# ema_32                     26994.842811
# ema_100                      27332.3134
# ema_200                    27424.986896
# vol_close                      0.003487
# vol_close_ema_3                0.003119
# vol_close_ema_6                0.003427
# vol_close_ema_12               0.003926
# Name: 27625, dtype: object
# Closed trade at step 27626
# ------------------------------> Trade outcome: 92.68999999999869
# Trade reached take profit
# Reward: 1.5
# Step: 27626
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 06:00:00
# open                           26876.85
# high                           26920.81
# low                            26838.01
# close                           26870.0
# volume usdt                    20600313
# tradecount                        32240
# hour                                  6
# day                                   4
# ema_13                     26854.726114
# ema_25                     26933.752566
# ema_32                      26987.27658
# ema_100                    27323.158679
# ema_200                    27419.464639
# vol_close                      0.003082
# vol_close_ema_3                  0.0031
# vol_close_ema_6                0.003329
# vol_close_ema_12               0.003796
# Name: 27626, dtype: object
# Reward: 0
# Step: 27627
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 07:00:00
# open                           26870.01
# high                           26876.44
# low                             26804.8
# close                          26810.66
# volume usdt                    25957678
# tradecount                        44181
# hour                                  7
# day                                   4
# ema_13                     26848.430955
# ema_25                     26924.283907
# ema_32                     26976.572545
# ema_100                     27313.01019
# ema_200                    27413.406881
# vol_close                      0.002672
# vol_close_ema_3                0.002886
# vol_close_ema_6                0.003141
# vol_close_ema_12               0.003623
# Name: 27627, dtype: object
# Reward: 0
# Step: 27628
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 08:00:00
# open                           26810.66
# high                           26824.59
# low                            26771.19
# close                           26802.8
# volume usdt                    23767406
# tradecount                        48649
# hour                                  8
# day                                   4
# ema_13                     26841.912247
# ema_25                     26914.938991
# ema_32                     26966.040875
# ema_100                    27302.907018
# ema_200                    27407.331191
# vol_close                      0.001992
# vol_close_ema_3                0.002439
# vol_close_ema_6                0.002813
# vol_close_ema_12               0.003372
# Name: 27628, dtype: object
# Reward: 0
# Step: 27629
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 09:00:00
# open                           26802.81
# high                           26824.12
# low                             26655.6
# close                           26742.3
# volume usdt                    57725880
# tradecount                        68979
# hour                                  9
# day                                   4
# ema_13                     26827.681926
# ema_25                     26901.659068
# ema_32                     26952.480822
# ema_100                    27291.805889
# ema_200                    27400.713965
# vol_close                      0.006302
# vol_close_ema_3                 0.00437
# vol_close_ema_6                 0.00381
# vol_close_ema_12               0.003823
# Name: 27629, dtype: object
# Reward: 0
# Step: 27630
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 10:00:00
# open                            26742.3
# high                           26782.93
# low                            26732.73
# close                          26754.79
# volume usdt                    22701781
# tradecount                        41251
# hour                                 10
# day                                   4
# ema_13                     26817.268794
# ema_25                     26890.361448
# ema_32                      26940.49956
# ema_100                    27281.171911
# ema_200                    27394.286861
# vol_close                      0.001876
# vol_close_ema_3                0.003123
# vol_close_ema_6                0.003257
# vol_close_ema_12               0.003524
# Name: 27630, dtype: object
# Reward: 0
# Step: 27631
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 11:00:00
# open                            26754.8
# high                           26867.14
# low                            26721.79
# close                          26837.84
# volume usdt                    29951354
# tradecount                        44361
# hour                                 11
# day                                   4
# ema_13                     26820.207538
# ema_25                     26886.321336
# ema_32                     26934.277769
# ema_100                    27272.393061
# ema_200                    27388.750076
# vol_close                      0.005416
# vol_close_ema_3                 0.00427
# vol_close_ema_6                0.003874
# vol_close_ema_12               0.003815
# Name: 27631, dtype: object
# Reward: 0
# Step: 27632
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 12:00:00
# open                           26837.84
# high                           26857.25
# low                             26753.2
# close                          26829.99
# volume usdt                    33089202
# tradecount                        61837
# hour                                 12
# day                                   4
# ema_13                     26821.605032
# ema_25                     26881.988157
# ema_32                     26927.957298
# ema_100                    27263.632605
# ema_200                    27383.190274
# vol_close                      0.003878
# vol_close_ema_3                0.004074
# vol_close_ema_6                0.003875
# vol_close_ema_12               0.003824
# Name: 27632, dtype: object
# Reward: 0
# Step: 27633
# Open Position: 0
# Trades: 4334 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 13:00:00
# open                            26830.0
# high                           26862.74
# low                            26685.71
# close                           26761.6
# volume usdt                    33484041
# tradecount                        63884
# hour                                 13
# day                                   4
# ema_13                     26813.032885
# ema_25                     26872.727529
# ema_32                     26917.875038
# ema_100                    27253.691365
# ema_200                    27377.005297
# vol_close                      0.006615
# vol_close_ema_3                0.005344
# vol_close_ema_6                0.004658
# vol_close_ema_12               0.004254
# Name: 27633, dtype: object
# Opened trade at step 27634 with position size: 1501.73
# Reward: 0
# Step: 27634
# Open Position: 1
# Trades: 4335 | Profit/Loss: 20034.61
# Balance: 30034.61
# Winning Trades: 2247 | Losing Trades: 2087
# Overall Rewards: -177.40
# date                2023-10-12 14:00:00
# open                            26761.6
# high                           26778.89
# low                            26633.57
# close                          26701.94
# volume usdt                    28811399
# tradecount                        62918
# hour                                 14
# day                                   4
# ema_13                     26797.162473
# ema_25                     26859.590027
# ema_32                     26904.788066
# ema_100                    27242.765595
# ema_200                    27370.288229
# vol_close                      0.005442
# vol_close_ema_3                0.005393
# vol_close_ema_6                0.004882
# vol_close_ema_12               0.004437
# Name: 27634, dtype: object
# Closed trade at step 27635
# ------------------------------> Trade outcome: -59.669999999998254
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 27635
# Open Position: 0
# Trades: 4335 | Profit/Loss: 19974.94
# Balance: 29974.94
# Winning Trades: 2247 | Losing Trades: 2088
# Overall Rewards: -179.10
# date                2023-10-12 15:00:00
# open                           26701.93
# high                           26734.58
# low                            26621.76
# close                           26675.0
# volume usdt                    26807608
# tradecount                        56004
# hour                                 15
# day                                   4
# ema_13                     26779.710691
# ema_25                     26845.390794
# ema_32                     26890.861516
# ema_100                    27231.522712
# ema_200                    27363.369938
# vol_close                      0.004229
# vol_close_ema_3                0.004811
# vol_close_ema_6                0.004696
# vol_close_ema_12               0.004405
# Name: 27635, dtype: object
# Opened trade at step 27636 with position size: 1498.75
# Reward: 0
# Step: 27636
# Open Position: 1
# Trades: 4336 | Profit/Loss: 19974.94
# Balance: 29974.94
# Winning Trades: 2247 | Losing Trades: 2088
# Overall Rewards: -179.10
# date                2023-10-12 16:00:00
# open                           26674.99
# high                           26804.99
# low                            26566.15
# close                          26673.36
# volume usdt                    54542118
# tradecount                        81576
# hour                                 16
# day                                   4
# ema_13                     26764.517735
# ema_25                     26832.157656
# ema_32                     26877.679606
# ema_100                    27220.469985
# ema_200                    27356.504168
# vol_close                      0.008954
# vol_close_ema_3                0.006883
# vol_close_ema_6                0.005912
# vol_close_ema_12               0.005105
# Name: 27636, dtype: object
# Closed trade at step 27637
# ------------------------------> Trade outcome: -1.6300000000010186
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 27637
# Open Position: 0
# Trades: 4336 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 17:00:00
# open                           26673.36
# high                           26692.65
# low                             26555.0
# close                           26641.9
# volume usdt                    36915801
# tradecount                        79978
# hour                                 17
# day                                   4
# ema_13                     26747.000916
# ema_25                     26817.522452
# ema_32                     26863.389933
# ema_100                    27209.013154
# ema_200                    27349.393678
# vol_close                      0.005167
# vol_close_ema_3                0.006025
# vol_close_ema_6                0.005699
# vol_close_ema_12               0.005114
# Name: 27637, dtype: object
# Opened trade at step 27638 with position size: 1498.67
# Reward: 0
# Step: 27638
# Open Position: 1
# Trades: 4337 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 18:00:00
# open                           26641.89
# high                           26729.25
# low                            26596.45
# close                          26658.06
# volume usdt                    23783239
# tradecount                        45572
# hour                                 18
# day                                   4
# ema_13                     26734.295071
# ema_25                     26805.256109
# ema_32                     26850.945695
# ema_100                    27198.103191
# ema_200                    27342.514736
# vol_close                      0.004982
# vol_close_ema_3                0.005503
# vol_close_ema_6                0.005494
# vol_close_ema_12               0.005094
# Name: 27638, dtype: object
# Reward: 0
# Step: 27639
# Open Position: 1
# Trades: 4337 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 19:00:00
# open                           26658.07
# high                           26739.95
# low                            26630.01
# close                           26712.9
# volume usdt                    16805676
# tradecount                        37880
# hour                                 19
# day                                   4
# ema_13                     26731.238632
# ema_25                     26798.151793
# ema_32                     26842.579289
# ema_100                    27188.495207
# ema_200                    27336.249913
# vol_close                      0.004116
# vol_close_ema_3                0.004809
# vol_close_ema_6                  0.0051
# vol_close_ema_12               0.004943
# Name: 27639, dtype: object
# Reward: 0
# Step: 27640
# Open Position: 1
# Trades: 4337 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 20:00:00
# open                           26712.91
# high                           26759.01
# low                            26706.84
# close                           26745.0
# volume usdt                    17793176
# tradecount                        32334
# hour                                 20
# day                                   4
# ema_13                     26733.204542
# ema_25                     26794.063194
# ema_32                     26836.665393
# ema_100                    27179.713123
# ema_200                    27330.366829
# vol_close                      0.001951
# vol_close_ema_3                 0.00338
# vol_close_ema_6                  0.0042
# vol_close_ema_12               0.004483
# Name: 27640, dtype: object
# Reward: 0
# Step: 27641
# Open Position: 1
# Trades: 4337 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 21:00:00
# open                           26744.99
# high                           26764.94
# low                            26710.32
# close                          26759.28
# volume usdt                    12140848
# tradecount                        22859
# hour                                 21
# day                                   4
# ema_13                     26736.929607
# ema_25                     26791.387564
# ema_32                     26831.975369
# ema_100                    27171.387715
# ema_200                    27324.684373
# vol_close                      0.002041
# vol_close_ema_3                0.002711
# vol_close_ema_6                0.003584
# vol_close_ema_12               0.004107
# Name: 27641, dtype: object
# Reward: 0
# Step: 27642
# Open Position: 1
# Trades: 4337 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 22:00:00
# open                           26759.28
# high                            26775.0
# low                            26731.41
# close                          26755.05
# volume usdt                    13365455
# tradecount                        23669
# hour                                 22
# day                                   4
# ema_13                     26739.518235
# ema_25                     26788.592366
# ema_32                     26827.313225
# ema_100                    27163.143404
# ema_200                     27319.01637
# vol_close                      0.001629
# vol_close_ema_3                 0.00217
# vol_close_ema_6                0.003025
# vol_close_ema_12               0.003726
# Name: 27642, dtype: object
# Reward: 0
# Step: 27643
# Open Position: 1
# Trades: 4337 | Profit/Loss: 19973.31
# Balance: 29973.31
# Winning Trades: 2247 | Losing Trades: 2089
# Overall Rewards: -180.80
# date                2023-10-12 23:00:00
# open                           26755.05
# high                            26765.6
# low                            26706.44
# close                          26759.63
# volume usdt                    11829407
# tradecount                        24087
# hour                                 23
# day                                   4
# ema_13                     26742.391344
# ema_25                     26786.364492
# ema_32                     26823.211212
# ema_100                    27155.153039
# ema_200                    27313.450336
# vol_close                      0.002211
# vol_close_ema_3                 0.00219
# vol_close_ema_6                0.002792
# vol_close_ema_12               0.003493
# Name: 27643, dtype: object
# Closed trade at step 27644
# ------------------------------> Trade outcome: 117.7400000000016
# Trade reached take profit
# Reward: 1.5
# Step: 27644
# Open Position: 0
# Trades: 4337 | Profit/Loss: 20091.05
# Balance: 30091.05
# Winning Trades: 2248 | Losing Trades: 2089
# Overall Rewards: -179.30
# date                2023-10-13 00:00:00
# open                           26759.63
# high                           26859.75
# low                             26750.0
# close                          26829.56
# volume usdt                    21825096
# tradecount                        41547
# hour                                  0
# day                                   5
# ema_13                     26754.844009
# ema_25                     26789.687223
# ema_32                     26823.595987
# ema_100                    27148.705652
# ema_200                    27308.635507
# vol_close                      0.004091
# vol_close_ema_3                 0.00314
# vol_close_ema_6                0.003163
# vol_close_ema_12               0.003585
# Name: 27644, dtype: object
# Reward: 0
# Step: 27645
# Open Position: 0
# Trades: 4337 | Profit/Loss: 20091.05
# Balance: 30091.05
# Winning Trades: 2248 | Losing Trades: 2089
# Overall Rewards: -179.30
# date                2023-10-13 01:00:00
# open                           26829.56
# high                           26876.06
# low                            26789.49
# close                          26793.56
# volume usdt                    15848046
# tradecount                        31221
# hour                                  1
# day                                   5
# ema_13                     26760.374865
# ema_25                     26789.985129
# ema_32                     26821.775624
# ema_100                    27141.673065
# ema_200                    27303.510377
# vol_close                      0.003231
# vol_close_ema_3                0.003186
# vol_close_ema_6                0.003183
# vol_close_ema_12                0.00353
# Name: 27645, dtype: object
# Reward: 0
# Step: 27646
# Open Position: 0
# Trades: 4337 | Profit/Loss: 20091.05
# Balance: 30091.05
# Winning Trades: 2248 | Losing Trades: 2089
# Overall Rewards: -179.30
# date                2023-10-13 02:00:00
# open                           26793.57
# high                           26809.82
# low                            26786.27
# close                           26809.2
# volume usdt                     9143012
# tradecount                        19542
# hour                                  2
# day                                   5
# ema_13                     26767.349884
# ema_25                     26791.463196
# ema_32                     26821.013465
# ema_100                     27135.08944
# ema_200                    27298.591866
# vol_close                      0.000878
# vol_close_ema_3                0.002032
# vol_close_ema_6                0.002524
# vol_close_ema_12               0.003122
# Name: 27646, dtype: object
# Reward: 0
# Step: 27647
# Open Position: 0
# Trades: 4337 | Profit/Loss: 20091.05
# Balance: 30091.05
# Winning Trades: 2248 | Losing Trades: 2089
# Overall Rewards: -179.30
# date                2023-10-13 03:00:00
# open                            26809.2
# high                           26830.77
# low                             26768.7
# close                          26781.69
# volume usdt                    14274025
# tradecount                        23137
# hour                                  3
# day                                   5
# ema_13                     26769.398472
# ema_25                     26790.711412
# ema_32                     26818.630225
# ema_100                    27128.091431
# ema_200                    27293.448564
# vol_close                      0.002318
# vol_close_ema_3                0.002175
# vol_close_ema_6                0.002465
# vol_close_ema_12               0.002999
# Name: 27647, dtype: object
# Opened trade at step 27648 with position size: 1504.55
# Reward: 0
# Step: 27648
# Open Position: 1
# Trades: 4338 | Profit/Loss: 20091.05
# Balance: 30091.05
# Winning Trades: 2248 | Losing Trades: 2089
# Overall Rewards: -179.30
# date                2023-10-13 04:00:00
# open                           26781.69
# high                           26806.71
# low                            26773.84
# close                          26805.52
# volume usdt                    10823394
# tradecount                        19216
# hour                                  4
# day                                   5
# ema_13                     26774.558691
# ema_25                     26791.850534
# ema_32                     26817.835665
# ema_100                    27121.703878
# ema_200                    27288.593553
# vol_close                      0.001226
# vol_close_ema_3                0.001701
# vol_close_ema_6                0.002111
# vol_close_ema_12               0.002726
# Name: 27648, dtype: object
# Reward: 0
# Step: 27649
# Open Position: 1
# Trades: 4338 | Profit/Loss: 20091.05
# Balance: 30091.05
# Winning Trades: 2248 | Losing Trades: 2089
# Overall Rewards: -179.30
# date                2023-10-13 05:00:00
# open                           26805.51
# high                           26828.22
# low                            26781.97
# close                          26821.92
# volume usdt                    17540371
# tradecount                        23442
# hour                                  5
# day                                   5
# ema_13                     26781.324592
# ema_25                      26794.16357
# ema_32                     26818.083201
# ema_100                    27115.767564
# ema_200                    27283.950036
# vol_close                      0.001724
# vol_close_ema_3                0.001712
# vol_close_ema_6                0.002001
# vol_close_ema_12               0.002572
# Name: 27649, dtype: object
# Closed trade at step 27650
# ------------------------------> Trade outcome: 40.22999999999956
# Trade reached take profit
# Reward: 1.5
# Step: 27650
# Open Position: 0
# Trades: 4338 | Profit/Loss: 20131.28
# Balance: 30131.28
# Winning Trades: 2249 | Losing Trades: 2089
# Overall Rewards: -177.80
# date                2023-10-13 06:00:00
# open                           26821.92
# high                            26860.0
# low                            26802.44
# close                          26808.17
# volume usdt                    12944372
# tradecount                        22333
# hour                                  6
# day                                   5
# ema_13                      26785.15965
# ema_25                     26795.240988
# ema_32                     26817.482401
# ema_100                    27109.676523
# ema_200                    27279.215906
# vol_close                      0.002147
# vol_close_ema_3                 0.00193
# vol_close_ema_6                0.002043
# vol_close_ema_12               0.002507
# Name: 27650, dtype: object
# Opened trade at step 27651 with position size: 1506.56
# Reward: 0
# Step: 27651
# Open Position: 1
# Trades: 4339 | Profit/Loss: 20131.28
# Balance: 30131.28
# Winning Trades: 2249 | Losing Trades: 2089
# Overall Rewards: -177.80
# date                2023-10-13 07:00:00
# open                           26808.18
# high                            26943.0
# low                            26808.17
# close                           26875.0
# volume usdt                    30461223
# tradecount                        47652
# hour                                  7
# day                                   5
# ema_13                     26797.993986
# ema_25                     26801.376296
# ema_32                     26820.968316
# ema_100                    27105.029463
# ema_200                    27275.193857
# vol_close                      0.005017
# vol_close_ema_3                0.003473
# vol_close_ema_6                0.002892
# vol_close_ema_12               0.002893
# Name: 27651, dtype: object
# Closed trade at step 27652
# ------------------------------> Trade outcome: 66.81000000000131
# Trade reached take profit
# Reward: 1.5
# Step: 27652
# Open Position: 0
# Trades: 4339 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 08:00:00
# open                           26874.99
# high                           26903.94
# low                             26787.6
# close                          26796.02
# volume usdt                    45511609
# tradecount                        43880
# hour                                  8
# day                                   5
# ema_13                     26797.711988
# ema_25                     26800.964273
# ema_32                     26819.456297
# ema_100                    27098.910464
# ema_200                    27270.425958
# vol_close                      0.004342
# vol_close_ema_3                0.003908
# vol_close_ema_6                0.003306
# vol_close_ema_12               0.003116
# Name: 27652, dtype: object
# Reward: 0
# Step: 27653
# Open Position: 0
# Trades: 4339 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 09:00:00
# open                           26796.01
# high                           26823.45
# low                             26737.4
# close                          26738.05
# volume usdt                    24074208
# tradecount                        35464
# hour                                  9
# day                                   5
# ema_13                     26789.188847
# ema_25                     26796.124714
# ema_32                     26814.522582
# ema_100                    27091.764712
# ema_200                    27265.128685
# vol_close                      0.003218
# vol_close_ema_3                0.003563
# vol_close_ema_6                0.003281
# vol_close_ema_12               0.003131
# Name: 27653, dtype: object
# Reward: 0
# Step: 27654
# Open Position: 0
# Trades: 4339 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 10:00:00
# open                           26738.05
# high                            26788.0
# low                            26738.05
# close                          26778.48
# volume usdt                    14094579
# tradecount                        25117
# hour                                 10
# day                                   5
# ema_13                     26787.659012
# ema_25                     26794.767428
# ema_32                     26812.338183
# ema_100                    27085.561054
# ema_200                    27260.286409
# vol_close                      0.001865
# vol_close_ema_3                0.002714
# vol_close_ema_6                0.002877
# vol_close_ema_12               0.002937
# Name: 27654, dtype: object
# Reward: 0
# Step: 27655
# Open Position: 0
# Trades: 4339 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 11:00:00
# open                           26778.48
# high                           26854.39
# low                            26778.47
# close                          26820.92
# volume usdt                    16046436
# tradecount                        33723
# hour                                 11
# day                                   5
# ema_13                     26792.410581
# ema_25                     26796.779165
# ema_32                     26812.858293
# ema_100                    27080.320638
# ema_200                    27255.914604
# vol_close                      0.002831
# vol_close_ema_3                0.002772
# vol_close_ema_6                0.002864
# vol_close_ema_12                0.00292
# Name: 27655, dtype: object
# Reward: 0
# Step: 27656
# Open Position: 0
# Trades: 4339 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 12:00:00
# open                           26820.91
# high                           26939.72
# low                            26764.72
# close                          26932.63
# volume usdt                    40365551
# tradecount                        65273
# hour                                 12
# day                                   5
# ema_13                     26812.441927
# ema_25                     26807.229229
# ema_32                     26820.117184
# ema_100                     27077.39607
# ema_200                    27252.697842
# vol_close                      0.006498
# vol_close_ema_3                0.004635
# vol_close_ema_6                0.003902
# vol_close_ema_12               0.003471
# Name: 27656, dtype: object
# Opened trade at step 27657 with position size: 1509.90
# Reward: 0
# Step: 27657
# Open Position: 1
# Trades: 4340 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 13:00:00
# open                           26932.63
# high                           26966.85
# low                            26833.19
# close                          26855.63
# volume usdt                    40536828
# tradecount                        77597
# hour                                 13
# day                                   5
# ema_13                     26818.611652
# ema_25                     26810.952365
# ema_32                     26822.269476
# ema_100                    27073.004663
# ema_200                    27248.746918
# vol_close                      0.004977
# vol_close_ema_3                0.004806
# vol_close_ema_6                0.004209
# vol_close_ema_12               0.003702
# Name: 27657, dtype: object
# Reward: 0
# Step: 27658
# Open Position: 1
# Trades: 4340 | Profit/Loss: 20198.09
# Balance: 30198.09
# Winning Trades: 2250 | Losing Trades: 2089
# Overall Rewards: -176.30
# date                2023-10-13 14:00:00
# open                           26855.64
# high                           26855.64
# low                            26734.65
# close                          26757.09
# volume usdt                    29664445
# tradecount                        65215
# hour                                 14
# day                                   5
# ema_13                     26809.822844
# ema_25                     26806.809106
# ema_32                     26818.319205
# ema_100                    27066.748927
# ema_200                    27243.854809
# vol_close                      0.004522
# vol_close_ema_3                0.004664
# vol_close_ema_6                0.004298
# vol_close_ema_12               0.003828
# Name: 27658, dtype: object
# Closed trade at step 27659
# ------------------------------> Trade outcome: -175.54999999999927
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 27659
# Open Position: 0
# Trades: 4340 | Profit/Loss: 20022.54
# Balance: 30022.54
# Winning Trades: 2250 | Losing Trades: 2090
# Overall Rewards: -178.00
# date                2023-10-13 15:00:00
# open                           26757.08
# high                           26784.27
# low                            26685.96
# close                          26706.83
# volume usdt                    28121839
# tradecount                        50761
# hour                                 15
# day                                   5
# ema_13                     26795.109581
# ema_25                     26799.118406
# ema_32                     26811.562283
# ema_100                     27059.62182
# ema_200                    27238.511279
# vol_close                      0.003681
# vol_close_ema_3                0.004172
# vol_close_ema_6                0.004122
# vol_close_ema_12               0.003806
# Name: 27659, dtype: object
# Opened trade at step 27660 with position size: 1501.13
# Reward: 0
# Step: 27660
# Open Position: 1
# Trades: 4341 | Profit/Loss: 20022.54
# Balance: 30022.54
# Winning Trades: 2250 | Losing Trades: 2090
# Overall Rewards: -178.00
# date                2023-10-13 16:00:00
# open                           26706.83
# high                            26807.1
# low                            26701.38
# close                          26796.73
# volume usdt                    26721201
# tradecount                        43631
# hour                                 16
# day                                   5
# ema_13                     26795.341069
# ema_25                     26798.934682
# ema_32                     26810.663357
# ema_100                    27054.416041
# ema_200                    27234.115445
# vol_close                      0.003945
# vol_close_ema_3                0.004059
# vol_close_ema_6                0.004072
# vol_close_ema_12               0.003827
# Name: 27660, dtype: object
# Closed trade at step 27661
# ------------------------------> Trade outcome: 89.89999999999782
# Trade reached take profit
# Reward: 1.5
# Step: 27661
# Open Position: 0
# Trades: 4341 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 17:00:00
# open                           26796.73
# high                           26798.31
# low                             26685.0
# close                          26768.26
# volume usdt                    25827019
# tradecount                        38747
# hour                                 17
# day                                   5
# ema_13                     26791.472345
# ema_25                     26796.575091
# ema_32                     26808.093457
# ema_100                    27048.749585
# ema_200                    27229.480068
# vol_close                      0.004233
# vol_close_ema_3                0.004146
# vol_close_ema_6                0.004118
# vol_close_ema_12                0.00389
# Name: 27661, dtype: object
# Opened trade at step 27662 with position size: 1505.62
# Reward: 0
# Step: 27662
# Open Position: 1
# Trades: 4342 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 18:00:00
# open                           26768.26
# high                           26786.53
# low                            26730.29
# close                          26749.05
# volume usdt                    14730560
# tradecount                        31899
# hour                                 18
# day                                   5
# ema_13                      26785.41201
# ema_25                     26792.919315
# ema_32                     26804.515065
# ema_100                     27042.81494
# ema_200                    27224.699669
# vol_close                      0.002103
# vol_close_ema_3                0.003124
# vol_close_ema_6                0.003542
# vol_close_ema_12               0.003615
# Name: 27662, dtype: object
# Reward: 0
# Step: 27663
# Open Position: 1
# Trades: 4342 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 19:00:00
# open                           26749.04
# high                           26780.73
# low                             26723.0
# close                          26778.57
# volume usdt                    14719825
# tradecount                        31208
# hour                                 19
# day                                   5
# ema_13                      26784.43458
# ema_25                     26791.815522
# ema_32                     26802.942637
# ema_100                    27037.582367
# ema_200                    27220.260568
# vol_close                      0.002156
# vol_close_ema_3                 0.00264
# vol_close_ema_6                0.003146
# vol_close_ema_12                0.00339
# Name: 27663, dtype: object
# Reward: 0
# Step: 27664
# Open Position: 1
# Trades: 4342 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 20:00:00
# open                           26778.57
# high                           27074.07
# low                            26747.24
# close                          26981.36
# volume usdt                    52064635
# tradecount                        56957
# hour                                 20
# day                                   5
# ema_13                     26812.566783
# ema_25                     26806.395866
# ema_32                     26813.755811
# ema_100                    27036.469052
# ema_200                    27217.883448
# vol_close                      0.012113
# vol_close_ema_3                0.007377
# vol_close_ema_6                0.005708
# vol_close_ema_12               0.004732
# Name: 27664, dtype: object
# Reward: 0
# Step: 27665
# Open Position: 1
# Trades: 4342 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 21:00:00
# open                           26981.37
# high                            27130.0
# low                            26839.84
# close                           27019.2
# volume usdt                    77170714
# tradecount                        95922
# hour                                 21
# day                                   5
# ema_13                     26842.085814
# ema_25                     26822.765415
# ema_32                     26826.206974
# ema_100                    27036.127091
# ema_200                    27215.906498
# vol_close                      0.010739
# vol_close_ema_3                0.009058
# vol_close_ema_6                0.007145
# vol_close_ema_12               0.005656
# Name: 27665, dtype: object
# Reward: 0
# Step: 27666
# Open Position: 1
# Trades: 4342 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 22:00:00
# open                            27019.2
# high                           27078.73
# low                            26755.01
# close                           26829.9
# volume usdt                    46684721
# tradecount                        73262
# hour                                 22
# day                                   5
# ema_13                     26840.344983
# ema_25                     26823.314229
# ema_32                     26826.430793
# ema_100                    27032.043386
# ema_200                    27212.065638
# vol_close                      0.012066
# vol_close_ema_3                0.010562
# vol_close_ema_6                0.008551
# vol_close_ema_12               0.006642
# Name: 27666, dtype: object
# Reward: 0
# Step: 27667
# Open Position: 1
# Trades: 4342 | Profit/Loss: 20112.44
# Balance: 30112.44
# Winning Trades: 2251 | Losing Trades: 2090
# Overall Rewards: -176.50
# date                2023-10-13 23:00:00
# open                            26829.9
# high                            26862.0
# low                            26764.65
# close                           26862.0
# volume usdt                    18360088
# tradecount                        38576
# hour                                 23
# day                                   5
# ema_13                     26843.438557
# ema_25                     26826.290058
# ema_32                     26828.586503
# ema_100                     27028.67619
# ema_200                    27208.582397
# vol_close                      0.003624
# vol_close_ema_3                0.007093
# vol_close_ema_6                0.007143
# vol_close_ema_12               0.006178
# Name: 27667, dtype: object
# Closed trade at step 27668
# ------------------------------> Trade outcome: 93.7400000000016
# Trade reached take profit
# Reward: 1.5
# Step: 27668
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 00:00:00
# open                            26862.0
# high                           26899.67
# low                            26852.49
# close                          26892.46
# volume usdt                    14480178
# tradecount                        25807
# hour                                  0
# day                                   6
# ema_13                      26850.44162
# ema_25                     26831.380053
# ema_32                     26832.457624
# ema_100                     27025.97884
# ema_200                    27205.436901
# vol_close                      0.001754
# vol_close_ema_3                0.004424
# vol_close_ema_6                0.005604
# vol_close_ema_12               0.005498
# Name: 27668, dtype: object
# Reward: 0
# Step: 27669
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 01:00:00
# open                           26892.45
# high                           26929.47
# low                             26845.0
# close                          26915.05
# volume usdt                    14781227
# tradecount                        24570
# hour                                  1
# day                                   6
# ema_13                     26859.671389
# ema_25                     26837.816203
# ema_32                     26837.463223
# ema_100                    27023.782229
# ema_200                    27202.547479
# vol_close                      0.003138
# vol_close_ema_3                0.003781
# vol_close_ema_6                0.004899
# vol_close_ema_12               0.005135
# Name: 27669, dtype: object
# Reward: 0
# Step: 27670
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 02:00:00
# open                           26915.05
# high                           26933.88
# low                            26887.41
# close                           26905.0
# volume usdt                    10594236
# tradecount                        24242
# hour                                  2
# day                                   6
# ema_13                     26866.146905
# ema_25                     26842.984187
# ema_32                     26841.556361
# ema_100                    27021.430106
# ema_200                    27199.586808
# vol_close                      0.001727
# vol_close_ema_3                0.002754
# vol_close_ema_6                0.003993
# vol_close_ema_12                0.00461
# Name: 27670, dtype: object
# Reward: 0
# Step: 27671
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 03:00:00
# open                            26905.0
# high                           26989.58
# low                             26905.0
# close                          26930.78
# volume usdt                    18396974
# tradecount                        25691
# hour                                  3
# day                                   6
# ema_13                     26875.380204
# ema_25                     26849.737711
# ema_32                     26846.963854
# ema_100                    27019.635054
# ema_200                    27196.912113
# vol_close                      0.003141
# vol_close_ema_3                0.002947
# vol_close_ema_6                0.003749
# vol_close_ema_12               0.004384
# Name: 27671, dtype: object
# Reward: 0
# Step: 27672
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 04:00:00
# open                           26930.77
# high                           26934.72
# low                             26901.4
# close                          26908.43
# volume usdt                     8078915
# tradecount                        17309
# hour                                  4
# day                                   6
# ema_13                     26880.101604
# ema_25                     26854.252503
# ema_32                     26850.689075
# ema_100                    27017.432974
# ema_200                    27194.041644
# vol_close                      0.001238
# vol_close_ema_3                0.002093
# vol_close_ema_6                0.003032
# vol_close_ema_12                 0.0039
# Name: 27672, dtype: object
# Reward: 0
# Step: 27673
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 05:00:00
# open                           26908.43
# high                           26939.35
# low                             26882.2
# close                          26885.07
# volume usdt                    12037832
# tradecount                        21103
# hour                                  5
# day                                   6
# ema_13                     26880.811374
# ema_25                      26856.62308
# ema_32                     26852.772767
# ema_100                    27014.811925
# ema_200                    27190.967299
# vol_close                      0.002126
# vol_close_ema_3                0.002109
# vol_close_ema_6                0.002773
# vol_close_ema_12               0.003627
# Name: 27673, dtype: object
# Reward: 0
# Step: 27674
# Open Position: 0
# Trades: 4342 | Profit/Loss: 20206.18
# Balance: 30206.18
# Winning Trades: 2252 | Losing Trades: 2090
# Overall Rewards: -175.00
# date                2023-10-14 06:00:00
# open                           26885.06
# high                           26897.18
# low                             26850.0
# close                          26863.41
# volume usdt                    38372077
# tradecount                        30678
# hour                                  6
# day                                   6
# ema_13                     26878.325464
# ema_25                      26857.14515
# ema_32                     26853.417448
# ema_100                    27011.813867
# ema_200                    27187.708023
# vol_close                      0.001756
# vol_close_ema_3                0.001933
# vol_close_ema_6                0.002483
# vol_close_ema_12               0.003339
# Name: 27674, dtype: object
# ...
# vol_close_ema_12               0.003545
# Name: 27794, dtype: object
# Opened trade at step 27795 with position size: 1551.57
# Reward: 0
# Step: 27795
# Open Position: 1
# Trades: 4360 | Profit/Loss: 21031.43
# Balance: 31031.43
# Winning Trades: 2260 | Losing Trades: 2099
# Overall Rewards: -178.30
# date                2023-10-19 07:00:00
# open                           28291.15
# high                           28339.72
# low                            28242.67
# close                          28330.82
# volume usdt                    23563800
# tradecount                        35597
# hour                                  7
# day                                   4
# ema_13                     28300.691889
# ema_25                     28318.851426
# ema_32                     28318.190615
# ema_100                    28032.433888
# ema_200                    27746.547288
# vol_close                      0.003426
# vol_close_ema_3                0.002874
# vol_close_ema_6                0.003067
# vol_close_ema_12               0.003527
# Name: 27795, dtype: object
# Closed trade at step 27796
# ------------------------------> Trade outcome: 39.669999999998254
# Trade reached take profit
# Reward: 1.5
# Step: 27796
# Open Position: 0
# Trades: 4360 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 08:00:00
# open                           28330.82
# high                           28375.47
# low                            28302.95
# close                          28325.21
# volume usdt                    25557681
# tradecount                        37206
# hour                                  8
# day                                   4
# ema_13                     28304.194477
# ema_25                     28319.340547
# ema_32                     28318.616032
# ema_100                    28038.231435
# ema_200                    27752.305126
# vol_close                       0.00256
# vol_close_ema_3                0.002717
# vol_close_ema_6                0.002923
# vol_close_ema_12               0.003378
# Name: 27796, dtype: object
# Reward: 0
# Step: 27797
# Open Position: 0
# Trades: 4360 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 09:00:00
# open                           28325.22
# high                           28411.33
# low                            28280.96
# close                          28400.01
# volume usdt                    36058543
# tradecount                        48700
# hour                                  9
# day                                   4
# ema_13                     28317.882409
# ema_25                      28325.54589
# ema_32                        28323.549
# ema_100                    28045.395367
# ema_200                     27758.74995
# vol_close                       0.00459
# vol_close_ema_3                0.003654
# vol_close_ema_6                0.003399
# vol_close_ema_12               0.003565
# Name: 27797, dtype: object
# Opened trade at step 27798 with position size: 1553.55
# Reward: 0
# Step: 27798
# Open Position: 1
# Trades: 4361 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 10:00:00
# open                            28400.0
# high                           28514.21
# low                            28375.86
# close                          28476.99
# volume usdt                    57401011
# tradecount                        71755
# hour                                 10
# day                                   4
# ema_13                     28340.612064
# ema_25                     28337.195437
# ema_32                     28332.848454
# ema_100                    28053.941795
# ema_200                    27765.896618
# vol_close                      0.004858
# vol_close_ema_3                0.004256
# vol_close_ema_6                0.003816
# vol_close_ema_12               0.003764
# Name: 27798, dtype: object
# Reward: 0
# Step: 27799
# Open Position: 1
# Trades: 4361 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 11:00:00
# open                            28477.0
# high                            28495.0
# low                             28410.0
# close                          28450.69
# volume usdt                    29375095
# tradecount                        40194
# hour                                 11
# day                                   4
# ema_13                     28356.337484
# ema_25                     28345.925788
# ema_32                     28339.990366
# ema_100                    28061.798195
# ema_200                    27772.710482
# vol_close                      0.002988
# vol_close_ema_3                0.003622
# vol_close_ema_6                0.003579
# vol_close_ema_12               0.003644
# Name: 27799, dtype: object
# Reward: 0
# Step: 27800
# Open Position: 1
# Trades: 4361 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 12:00:00
# open                            28450.7
# high                           28573.74
# low                             28420.0
# close                          28477.12
# volume usdt                    60058313
# tradecount                        77747
# hour                                 12
# day                                   4
# ema_13                     28373.592129
# ema_25                      28356.01765
# ema_32                     28348.301253
# ema_100                    28070.022389
# ema_200                    27779.719532
# vol_close                      0.005399
# vol_close_ema_3                 0.00451
# vol_close_ema_6                0.004099
# vol_close_ema_12               0.003914
# Name: 27800, dtype: object
# Reward: 0
# Step: 27801
# Open Position: 1
# Trades: 4361 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 13:00:00
# open                           28477.12
# high                            28587.3
# low                            28435.42
# close                          28482.09
# volume usdt                    52258517
# tradecount                        68763
# hour                                 13
# day                                   4
# ema_13                     28389.091825
# ema_25                     28365.715523
# ema_32                     28356.409662
# ema_100                    28078.182144
# ema_200                    27786.708293
# vol_close                      0.005332
# vol_close_ema_3                0.004921
# vol_close_ema_6                0.004452
# vol_close_ema_12               0.004132
# Name: 27801, dtype: object
# Reward: 0
# Step: 27802
# Open Position: 1
# Trades: 4361 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 14:00:00
# open                            28482.1
# high                           28750.57
# low                            28444.64
# close                          28680.45
# volume usdt                    86267966
# tradecount                        98763
# hour                                 14
# day                                   4
# ema_13                     28430.714421
# ema_25                     28389.925868
# ema_32                      28376.04847
# ema_100                     28090.10824
# ema_200                    27795.601245
# vol_close                      0.010667
# vol_close_ema_3                0.007794
# vol_close_ema_6                0.006227
# vol_close_ema_12               0.005138
# Name: 27802, dtype: object
# Reward: 0
# Step: 27803
# Open Position: 1
# Trades: 4361 | Profit/Loss: 21071.10
# Balance: 31071.10
# Winning Trades: 2261 | Losing Trades: 2099
# Overall Rewards: -176.80
# date                2023-10-19 15:00:00
# open                           28680.45
# high                           28814.14
# low                            28569.28
# close                          28680.09
# volume usdt                    93044459
# tradecount                       127216
# hour                                 15
# day                                   4
# ema_13                     28466.339504
# ema_25                     28412.246185
# ema_32                      28394.47523
# ema_100                    28101.791047
# ema_200                    27804.402128
# vol_close                      0.008538
# vol_close_ema_3                0.008166
# vol_close_ema_6                0.006887
# vol_close_ema_12               0.005661
# Name: 27803, dtype: object
# Closed trade at step 27804
# ------------------------------> Trade outcome: 280.09000000000015
# Trade reached take profit
# Reward: 1.5
# Step: 27804
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 16:00:00
# open                           28680.09
# high                           28916.89
# low                            28606.32
# close                          28620.01
# volume usdt                   111887693
# tradecount                       134118
# hour                                 16
# day                                   4
# ema_13                     28488.292432
# ema_25                     28428.228017
# ema_32                     28408.144004
# ema_100                    28112.052809
# ema_200                     27812.51763
# vol_close                      0.010851
# vol_close_ema_3                0.009509
# vol_close_ema_6                 0.00802
# vol_close_ema_12               0.006459
# Name: 27804, dtype: object
# Reward: 0
# Step: 27805
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 17:00:00
# open                           28620.01
# high                           28692.48
# low                            28457.56
# close                          28547.24
# volume usdt                    48562825
# tradecount                        75653
# hour                                 17
# day                                   4
# ema_13                     28496.713513
# ema_25                     28437.382785
# ema_32                     28416.574064
# ema_100                    28120.670377
# ema_200                      27819.8283
# vol_close                      0.008229
# vol_close_ema_3                0.008869
# vol_close_ema_6                 0.00808
# vol_close_ema_12               0.006732
# Name: 27805, dtype: object
# Reward: 0
# Step: 27806
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 18:00:00
# open                           28547.24
# high                           28691.42
# low                             28525.0
# close                          28646.98
# volume usdt                    40118201
# tradecount                        56412
# hour                                 18
# day                                   4
# ema_13                     28518.180154
# ema_25                     28453.505648
# ema_32                      28430.53806
# ema_100                    28131.092349
# ema_200                    27828.058665
# vol_close                      0.005809
# vol_close_ema_3                0.007339
# vol_close_ema_6                0.007431
# vol_close_ema_12                0.00659
# Name: 27806, dtype: object
# Reward: 0
# Step: 27807
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 19:00:00
# open                           28646.98
# high                           28765.76
# low                             28645.0
# close                          28750.75
# volume usdt                    29840591
# tradecount                        49985
# hour                                 19
# day                                   4
# ema_13                     28551.404418
# ema_25                     28476.370598
# ema_32                     28449.944844
# ema_100                    28143.362798
# ema_200                    27837.239673
# vol_close                        0.0042
# vol_close_ema_3                 0.00577
# vol_close_ema_6                0.006508
# vol_close_ema_12               0.006222
# Name: 27807, dtype: object
# Reward: 0
# Step: 27808
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 20:00:00
# open                           28750.75
# high                           28882.07
# low                             28684.8
# close                          28715.38
# volume usdt                    49976234
# tradecount                        59830
# hour                                 20
# day                                   4
# ema_13                     28574.829501
# ema_25                     28494.755937
# ema_32                     28466.031824
# ema_100                    28154.689871
# ema_200                    27845.977388
# vol_close                       0.00687
# vol_close_ema_3                 0.00632
# vol_close_ema_6                0.006611
# vol_close_ema_12               0.006322
# Name: 27808, dtype: object
# Reward: 0
# Step: 27809
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 21:00:00
# open                           28715.39
# high                           28739.73
# low                            28604.09
# close                          28604.09
# volume usdt                    32056663
# tradecount                        42623
# hour                                 21
# day                                   4
# ema_13                     28579.009572
# ema_25                     28503.166249
# ema_32                     28474.398986
# ema_100                    28163.588884
# ema_200                    27853.520797
# vol_close                      0.004742
# vol_close_ema_3                0.005531
# vol_close_ema_6                0.006077
# vol_close_ema_12               0.006079
# Name: 27809, dtype: object
# Reward: 0
# Step: 27810
# Open Position: 0
# Trades: 4361 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 22:00:00
# open                           28604.09
# high                           28704.99
# low                             28598.6
# close                          28649.65
# volume usdt                    22004203
# tradecount                        28479
# hour                                 22
# day                                   4
# ema_13                     28589.101062
# ema_25                      28514.43423
# ema_32                     28485.020259
# ema_100                    28173.213856
# ema_200                    27861.442481
# vol_close                      0.003713
# vol_close_ema_3                0.004622
# vol_close_ema_6                0.005402
# vol_close_ema_12               0.005715
# Name: 27810, dtype: object
# Opened trade at step 27811 with position size: 1567.56
# Reward: 0
# Step: 27811
# Open Position: 1
# Trades: 4362 | Profit/Loss: 21351.19
# Balance: 31351.19
# Winning Trades: 2262 | Losing Trades: 2099
# Overall Rewards: -175.30
# date                2023-10-19 23:00:00
# open                           28649.64
# high                           28717.82
# low                            28630.19
# close                          28713.71
# volume usdt                    17582981
# tradecount                        27099
# hour                                 23
# day                                   4
# ema_13                     28606.902339
# ema_25                     28529.763135
# ema_32                     28498.880244
# ema_100                     28183.91675
# ema_200                    27869.922755
# vol_close                      0.003052
# vol_close_ema_3                0.003837
# vol_close_ema_6                 0.00473
# vol_close_ema_12               0.005305
# Name: 27811, dtype: object
# Validation Phase - Total Reward: 174.30
